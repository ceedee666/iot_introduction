# %% [markdown]
# # Objective of the Lecture
#
# The objective of this lecture is to provide a first introduction to the
# [Internet of Things](https://en.wikipedia.org/wiki/Internet_of_things) (IoT). To acchive this objective a
# ESP8266-based microcontroller is used. This micorcontroller is connected to a temperature and humidity sensor. Using
# [MicroPython](http://micropython.org/) data form this sensor is transmitted to the
# [AWS IoT Services](https://aws.amazon.com/iot/). Finally, the data is analysed using
# [AWS IoT Analytics](https://aws.amazon.com/iot-analytics/).
#
# ## Ressources
# Below is a list of tools and documents used during the course of this lecture.
# - MicroPython
#     - Quick start documentation for ESP8266-based microcontrollers: (http://docs.micropython.org/en/latest/esp8266/quickref.html)
#     - Installing the MicroPython firmware: (https://randomnerdtutorials.com/flash-upload-micropython-firmware-esp32-esp8266/)
#     - Curated list of MicroPython libraries: (http://awesome-micropython.com/)
# - IDE
#     - PyCharm IDE: (https://www.jetbrains.com/pycharm/)
#     - MicroPython Plugin für PyCharm: (https://github.com/vlasovskikh/intellij-micropython#installation)
#
#
# ## Passwords and Password Managers
# If you put devices or service on the internet it is important to consider security. Here is just one
# example of what can happen if you are not careful: (https://www.reddit.com/r/aws/comments/8rj9ep/my_aws_account_was_hacked/)!
#
# Consequently, it is very important that:
# - You need to make sure that you **never** publicly expose login information or certificated related to your AWS account.
# - You allways use strong passwords. Here is an nice example of weak and strong passwords:
#
# ![XKCD Password Strength](https://imgs.xkcd.com/comics/password_strength.png)
#
# ### Password Manager
# In my opinion the only sensible way to handle passwords is the usage of a password manager. With a
# password manager it is possible to use an individual passworts for every services.
# Furthermore, long and secure passwords can automatically be generated by password managers.
#
# Wikipedia has a nice [list of password managers](https://en.wikipedia.org/wiki/List_of_password_managers) including a detailed feature comparison. I currently use [Bitwarden](https://en.wikipedia.org/wiki/Bitwarden).
#
# For additional security you should also enable [two-factor authentication](https://en.wikipedia.org/wiki/Multi-factor_authentication) whenever possible.

# %% [markdown]
# # Navigation
# - [Next Section ➡️](./20_micro_controller_intro.ipynb)
